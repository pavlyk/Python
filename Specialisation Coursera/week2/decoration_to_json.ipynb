# %%
import functools
import json


def to_json(func):

    @functools.wraps(func)
    def wrapped(*args, **kwargs):
        result = func(*args, **kwargs)
        return json.dumps(result)

    return wrapped

# %%
@to_json
def get_data():
  return {'data': 42, 'data2':[1,2,3]}
  
get_data()
# Out:
#   File "<ipython-input-5-e9d42dcead7e>", line 3
#     return {'data': 42, [1,2,3]}
#                                ^
# SyntaxError: invalid syntax
